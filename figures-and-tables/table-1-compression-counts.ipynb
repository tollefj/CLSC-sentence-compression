# %% [markdown]
# # Compression counts
# Display the number of original samples, compared to the reduced ones.

# %%
import numpy as np

def compress(df, lang1, lang2, MAX_SIZE=400_000):
    compressions = {}

    src_len = df[lang1].str.len()
    tgt_len = df[lang2].str.len()
    mean_len = (tgt_len / src_len).mean()

    compressions["length_ratio"] = mean_len
    print(f"Length ratio between {lang1} and {lang2}: {mean_len}")

    for comp_rate in np.arange(0.5, 1.05, 0.1):
        comp_rate = round(comp_rate, 1)
        print(f"Compression rate: {comp_rate}")
        compressed = df[
            df[lang2].str.len() < mean_len * comp_rate * df[lang1].str.len()
        ]
        print(compressed.describe())
        reduced = compressed.sample(
            n=min(MAX_SIZE, compressed.shape[0]), random_state=42
        )
        compressions[comp_rate] = {
            "compression_rate": comp_rate,
            "count": len(compressed),
            f"unique_{lang1}": compressed[lang1].unique().shape[0],
            f"unique_{lang2}": compressed[lang2].unique().shape[0],
            "count_reduced": len(reduced),
            f"unique_{lang1}_reduced": reduced[lang1].unique().shape[0],
            f"unique_{lang2}_reduced": reduced[lang2].unique().shape[0],
        }

    return compressions

# %%
import os
import pandas as pd

path = "../data/opensubtitles/datasets"

all_compressions = {}
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        print(filename)
        lang1, lang2 = filename.split(".")[0].split("-")
        print(lang1, lang2)
        df = pd.read_csv(os.path.join(path, filename))
        all_compressions[filename] = compress(df, lang1, lang2)
# Out:
# en-no.csv
# en no
# Length ratio between en and no: 0.9621212692882832
# Compression rate: 0.5
#                 en      no
# count       415797  415797
# unique      383220  255689
# top     All right.     Ja.
# freq          1107    7964
# Compression rate: 0.6
#                 en      no
# count       749826  749826
# unique      676004  491008
# top     Thank you.   Takk.
# freq          9250   12353
# Compression rate: 0.7
#              en       no
# count   1224125  1224125
# unique  1063829   819239
# top       Yeah.      Ja.
# freq      12507    21771
# Compression rate: 0.8
#              en       no
# count   1812989  1812989
# unique  1555327  1257908
# top       Yeah.      Ja.
# freq      12507    32970
# Compression rate: 0.9
#              en       no
# count   2514408  2514408
# unique  2126521  1787814
# top       Yeah.      Ja.
# freq      12806    32970
# Compression rate: 1.0
#              en       no
# count   3261374  3261374
# unique  2745492  2377950
# top       Yeah.      Ja.
# freq      12806    32970
# en-is.csv
# en is
# Length ratio between en and is: 1.0286267520786756
# Compression rate: 0.5
#                 en     is
# count        75880  75880
# unique       69037  47205
# top     Thank you.    Já.
# freq          1185   2434
# Compression rate: 0.6
#             en      is
# count   150171  150171
# unique  130424   97018
# top      Yeah.     Já.
# freq      4816    7403
# Compression rate: 0.7
#             en      is
# count   260511  260511
# unique  228343  182286
# top      Yeah.     Já.
# freq      4816    7403
# Compression rate: 0.8
#             en      is
# count   419985  419985
# unique  364470  306489
# top      Yeah.     Já.
# freq      4844    9990
# Compression rate: 0.9
#             en      is
# count   614276  614276
# unique  532030  464672
# top      Yeah.     Já.
# freq      4844    9990
# Compression rate: 1.0
#             en      is
# count   838767  838767
# unique  704140  629371
# top      Yeah.     Já.
# freq      4901   10086
# en-fr.csv
# en fr
# Length ratio between en and fr: 1.1054958747569195
# Compression rate: 0.5
#                 en       fr
# count      1806772  1806772
# unique     1515407   872836
# top     All right.     Oui.
# freq          7269    31975
# Compression rate: 0.6
#                 en       fr
# count      3548104  3548104
# unique     2879306  1903274
# top     Thank you.   Merci.
# freq         66007    83369
# Compression rate: 0.7
#                 en       fr
# count      6300807  6300807
# unique     5046597  3696144
# top     Thank you.   Merci.
# freq         66628    85001
# Compression rate: 0.8
#                 en        fr
# count     10141933  10141933
# unique     8015788   6362382
# top     Thank you.    Merci.
# freq         66931    114866
# Compression rate: 0.9
#                 en        fr
# count     14264796  14264796
# unique    11384951   9558068
# top     Thank you.    Merci.
# freq         67169    114866
# Compression rate: 1.0
#                 en        fr
# count     20502881  20502881
# unique    15715084  13757772
# top     Thank you.      Oui.
# freq         68181    165827
# en-ms.csv
# en ms
# Length ratio between en and ms: 1.1246369079611462
# Compression rate: 0.5
#                 en     ms
# count        37351  37351
# unique       32603  23315
# top     I'm sorry.    Ya.
# freq           120    712
# Compression rate: 0.6
#            en     ms
# count   74119  74119
# unique  59215  46599
# top     Yeah.    Ya.
# freq     2081   2833
# Compression rate: 0.7
#             en      ms
# count   128568  128568
# unique  102749   87672
# top      Yeah.     Ya.
# freq      2081    4385
# Compression rate: 0.8
#             en      ms
# count   211236  211236
# unique  168184  152051
# top      What?     Ya.
# freq      2791    4385
# Compression rate: 0.9
#             en      ms
# count   364438  364438
# unique  275662  260190
# top      Yeah.     Ya.
# freq      3110    4452
# Compression rate: 1.0
#             en      ms
# count   460469  460469
# unique  360773  347193
# top      Yeah.     Ya.
# freq      3110    4452
# de-en.csv
# de en
# Length ratio between de and en: 1.0080319185719437
# Compression rate: 0.5
#             de      en
# count   665449  665449
# unique  541250  325734
# top     Hallo.  Sorry.
# freq      2951    6828
# Compression rate: 0.6
#              de       en
# count   1309492  1309492
# unique   982159   688800
# top       Nein.      No.
# freq      45464    51928
# Compression rate: 0.7
#              de       en
# count   2449707  2449707
# unique  1849643  1468345
# top       Nein.      No.
# freq      45464    51928
# Compression rate: 0.8
#              de       en
# count   4355457  4355457
# unique  3310545  2851736
# top       Nein.      No.
# freq      46011    52440
# Compression rate: 0.9
#              de       en
# count   6620283  6620283
# unique  5117560  4615254
# top       Nein.      No.
# freq      46011    52440
# Compression rate: 1.0
#              de       en
# count   9244596  9244596
# unique  6883682  6370028
# top       Nein.      No.
# freq      48006    52934
# en-sq.csv
# en sq
# Length ratio between en and sq: 1.050420763842886
# Compression rate: 0.5
#               en      sq
# count     102869  102869
# unique     87047   61356
# top     Come on.     Po.
# freq        1264    2614
# Compression rate: 0.6
#             en      sq
# count   196339  196339
# unique  153466  119296
# top      Yeah.     Po.
# freq      7679   10411
# Compression rate: 0.7
#             en      sq
# count   330680  330680
# unique  256241  216490
# top      Yeah.     Po.
# freq      7679   10411
# Compression rate: 0.8
#             en      sq
# count   527887  527887
# unique  407303  365753
# top      Yeah.     Po.
# freq      7737   14663
# Compression rate: 0.9
#             en      sq
# count   769454  769454
# unique  604039  565020
# top      Yeah.     Po.
# freq      7737   14663
# Compression rate: 1.0
#              en       sq
# count   1076166  1076166
# unique   822514   789637
# top       Yeah.      Po.
# freq       7984    14853
# da-en.csv
# da en
# Length ratio between da and en: 1.2310291861796794
# Compression rate: 0.5
#               da      en
# count     547322  547322
# unique    390627  252855
# top     Hvorfor?    Why?
# freq        8854   10739
# Compression rate: 0.6
#               da       en
# count    1088999  1088999
# unique    758570   579471
# top     Hvorfor?     Why?
# freq        9066    10753
# Compression rate: 0.7
#              da       en
# count   2236671  2236671
# unique  1529893  1317606
# top        Nej.      No.
# freq      33198    38438
# Compression rate: 0.8
#              da       en
# count   3768359  3768359
# unique  2764589  2547985
# top        Nej.      No.
# freq      33198    38438
# Compression rate: 0.9
#              da       en
# count   5932657  5932657
# unique  4214560  4015691
# top        Nej.      No.
# freq      33744    40075
# Compression rate: 1.0
#              da       en
# count   7284770  7284770
# unique  5204357  5063870
# top        Nej.      No.
# freq      33744    40075
# en-lt.csv
# en lt
# Length ratio between en and lt: 0.9890395828668636
# Compression rate: 0.5
#                          en     lt
# count                 69190  69190
# unique                62838  42967
# top     What are you doing?  Taip.
# freq                    261   1332
# Compression rate: 0.6
#                 en      lt
# count       134416  134416
# unique      115160   86738
# top     Thank you.   Ačiū.
# freq          2367    2878
# Compression rate: 0.7
#             en      lt
# count   240922  240922
# unique  194281  158744
# top      What?     Ką?
# freq      3333    3736
# Compression rate: 0.8
#             en      lt
# count   372663  372663
# unique  301085  261321
# top      What?     Ką?
# freq      3333    3922
# Compression rate: 0.9
#             en      lt
# count   532621  532621
# unique  432657  391059
# top      What?     Ką?
# freq      4109    3922
# Compression rate: 1.0
#             en      lt
# count   664991  664991
# unique  550683  510136
# top      What?     Ką?
# freq      4109    3922
# en-hu.csv
# en hu
# Length ratio between en and hu: 1.0121323791258023
# Compression rate: 0.5
#                           en       hu
# count                1560313  1560313
# unique               1231283   689923
# top     Where are you going?    Igen.
# freq                    5377    23241
# Compression rate: 0.6
#              en       hu
# count   3175010  3175010
# unique  2361787  1575052
# top       What?      Mi?
# freq      37204    42706
# Compression rate: 0.7
#              en       hu
# count   5937986  5937986
# unique  4346425  3300664
# top       What?      Mi?
# freq      37204    42706
# Compression rate: 0.8
#               en        hu
# count   10178195  10178195
# unique   7369956   6135209
# top        Okay.      Oké.
# freq       58428     64618
# Compression rate: 0.9
#                 en         hu
# count     15289547   15289547
# unique    11133057    9814348
# top     Thank you.  Köszönöm.
# freq         70890      69007
# Compression rate: 1.0
#               en        hu
# count   21522518  21522518
# unique  15220404  13906350
# top        Yeah.     Igen.
# freq      127084    137163
# en-eu.csv
# en eu
# Length ratio between en and eu: 1.0873887529615953
# Compression rate: 0.5
#                 en    eu
# count         7768  7768
# unique        7162  5387
# top     All right.  Bai.
# freq           127   189
# Compression rate: 0.6
#                 en     eu
# count        15606  15606
# unique       14026  11285
# top     All right.   Bai.
# freq           128    210
# Compression rate: 0.7
#                    en         eu
# count           28228      28228
# unique          25165      21426
# top     I don't know.  Ez dakit.
# freq              198        258
# Compression rate: 0.8
#            en     eu
# count   49363  49363
# unique  42564  37926
# top     Yeah.   Bai.
# freq      795   1079
# Compression rate: 0.9
#            en     eu
# count   72849  72849
# unique  63845  58612
# top     Yeah.   Bai.
# freq      795   1079
# Compression rate: 1.0
#             en      eu
# count   105692  105692
# unique   88730   82667
# top      Yeah.    Bai.
# freq       806    1683
# en-pl.csv
# en pl
# Length ratio between en and pl: 1.022421730337034
# Compression rate: 0.5
#               en       pl
# count    2105542  2105542
# unique   1834073  1115093
# top     Nothing.     Tak.
# freq        9081    33157
# Compression rate: 0.6
#              en       pl
# count   3810521  3810521
# unique  3138643  2121409
# top       What?      Co?
# freq      71192    87137
# Compression rate: 0.7
#              en       pl
# count   6275552  6275552
# unique  5010233  3712490
# top       What?      Co?
# freq      71192    87137
# Compression rate: 0.8
#              en       pl
# count   9399322  9399322
# unique  7411788  5913662
# top       Yeah.     Tak.
# freq      74074   106420
# Compression rate: 0.9
#               en        pl
# count   13174343  13174343
# unique  10300228   8677895
# top        Yeah.      Tak.
# freq       74074    106420
# Compression rate: 1.0
#               en        pl
# count   17491329  17491329
# unique  13189304  11523960
# top        Yeah.      Tak.
# freq       79508    159956

# %%
all_compressions
# Out:
# {'en-no.csv': {'length_ratio': 0.9621212692882832,
#   0.5: {'compression_rate': 0.5,
#    'count': 415797,
#    'unique_en': 383220,
#    'unique_no': 255689,
#    'count_reduced': 400000,
#    'unique_en_reduced': 368921,
#    'unique_no_reduced': 246698},
#   0.6: {'compression_rate': 0.6,
#    'count': 749826,
#    'unique_en': 676004,
#    'unique_no': 491008,
#    'count_reduced': 400000,
#    'unique_en_reduced': 365459,
#    'unique_no_reduced': 273546},
#   0.7: {'compression_rate': 0.7,
#    'count': 1224125,
#    'unique_en': 1063829,
#    'unique_no': 819239,
#    'count_reduced': 400000,
#    'unique_en_reduced': 356458,
#    'unique_no_reduced': 287246},
#   0.8: {'compression_rate': 0.8,
#    'count': 1812989,
#    'unique_en': 1555327,
#    'unique_no': 1257908,
#    'count_reduced': 400000,
#    'unique_en_reduced': 356176,
#    'unique_no_reduced': 302424},
#   0.9: {'compression_rate': 0.9,
#    'count': 2514408,
#    'unique_en': 2126521,
#    'unique_no': 1787814,
#    'count_reduced': 400000,
#    'unique_en_reduced': 355374,
#    'unique_no_reduced': 313149},
#   1.0: {'compression_rate': 1.0,
#    'count': 3261374,
#    'unique_en': 2745492,
#    'unique_no': 2377950,
#    'count_reduced': 400000,
#    'unique_en_reduced': 357277,
#    'unique_no_reduced': 323469}},
#  'en-is.csv': {'length_ratio': 1.0286267520786756,
#   0.5: {'compression_rate': 0.5,
#    'count': 75880,
#    'unique_en': 69037,
#    'unique_is': 47205,
#    'count_reduced': 75880,
#    'unique_en_reduced': 69037,
#    'unique_is_reduced': 47205},
#   0.6: {'compression_rate': 0.6,
#    'count': 150171,
#    'unique_en': 130424,
#    'unique_is': 97018,
#    'count_reduced': 150171,
#    'unique_en_reduced': 130424,
#    'unique_is_reduced': 97018},
#   0.7: {'compression_rate': 0.7,
#    'count': 260511,
#    'unique_en': 228343,
#    'unique_is': 182286,
#    'count_reduced': 260511,
#    'unique_en_reduced': 228343,
#    'unique_is_reduced': 182286},
#   0.8: {'compression_rate': 0.8,
#    'count': 419985,
#    'unique_en': 364470,
#    'unique_is': 306489,
#    'count_reduced': 400000,
#    'unique_en_reduced': 347632,
#    'unique_is_reduced': 292770},
#   0.9: {'compression_rate': 0.9,
#    'count': 614276,
#    'unique_en': 532030,
#    'unique_is': 464672,
#    'count_reduced': 400000,
#    'unique_en_reduced': 351299,
#    'unique_is_reduced': 309603},
#   1.0: {'compression_rate': 1.0,
#    'count': 838767,
#    'unique_en': 704140,
#    'unique_is': 629371,
#    'count_reduced': 400000,
#    'unique_en_reduced': 345061,
#    'unique_is_reduced': 312917}},
#  'en-fr.csv': {'length_ratio': 1.1054958747569195,
#   0.5: {'compression_rate': 0.5,
#    'count': 1806772,
#    'unique_en': 1515407,
#    'unique_fr': 872836,
#    'count_reduced': 400000,
#    'unique_en_reduced': 351245,
#    'unique_fr_reduced': 224329},
#   0.6: {'compression_rate': 0.6,
#    'count': 3548104,
#    'unique_en': 2879306,
#    'unique_fr': 1903274,
#    'count_reduced': 400000,
#    'unique_en_reduced': 346349,
#    'unique_fr_reduced': 255708},
#   0.7: {'compression_rate': 0.7,
#    'count': 6300807,
#    'unique_en': 5046597,
#    'unique_fr': 3696144,
#    'count_reduced': 400000,
#    'unique_en_reduced': 349014,
#    'unique_fr_reduced': 283976},
#   0.8: {'compression_rate': 0.8,
#    'count': 10141933,
#    'unique_en': 8015788,
#    'unique_fr': 6362382,
#    'count_reduced': 400000,
#    'unique_en_reduced': 350602,
#    'unique_fr_reduced': 304110},
#   0.9: {'compression_rate': 0.9,
#    'count': 14264796,
#    'unique_en': 11384951,
#    'unique_fr': 9558068,
#    'count_reduced': 400000,
#    'unique_en_reduced': 356467,
#    'unique_fr_reduced': 322229},
#   1.0: {'compression_rate': 1.0,
#    'count': 20502881,
#    'unique_en': 15715084,
#    'unique_fr': 13757772,
#    'count_reduced': 400000,
#    'unique_en_reduced': 352392,
#    'unique_fr_reduced': 327682}},
#  'en-ms.csv': {'length_ratio': 1.1246369079611462,
#   0.5: {'compression_rate': 0.5,
#    'count': 37351,
#    'unique_en': 32603,
#    'unique_ms': 23315,
#    'count_reduced': 37351,
#    'unique_en_reduced': 32603,
#    'unique_ms_reduced': 23315},
#   0.6: {'compression_rate': 0.6,
#    'count': 74119,
#    'unique_en': 59215,
#    'unique_ms': 46599,
#    'count_reduced': 74119,
#    'unique_en_reduced': 59215,
#    'unique_ms_reduced': 46599},
#   0.7: {'compression_rate': 0.7,
#    'count': 128568,
#    'unique_en': 102749,
#    'unique_ms': 87672,
#    'count_reduced': 128568,
#    'unique_en_reduced': 102749,
#    'unique_ms_reduced': 87672},
#   0.8: {'compression_rate': 0.8,
#    'count': 211236,
#    'unique_en': 168184,
#    'unique_ms': 152051,
#    'count_reduced': 211236,
#    'unique_en_reduced': 168184,
#    'unique_ms_reduced': 152051},
#   0.9: {'compression_rate': 0.9,
#    'count': 364438,
#    'unique_en': 275662,
#    'unique_ms': 260190,
#    'count_reduced': 364438,
#    'unique_en_reduced': 275662,
#    'unique_ms_reduced': 260190},
#   1.0: {'compression_rate': 1.0,
#    'count': 460469,
#    'unique_en': 360773,
#    'unique_ms': 347193,
#    'count_reduced': 400000,
#    'unique_en_reduced': 315865,
#    'unique_ms_reduced': 304218}},
#  'de-en.csv': {'length_ratio': 1.0080319185719437,
#   0.5: {'compression_rate': 0.5,
#    'count': 665449,
#    'unique_de': 541250,
#    'unique_en': 325734,
#    'count_reduced': 400000,
#    'unique_de_reduced': 332157,
#    'unique_en_reduced': 206634},
#   0.6: {'compression_rate': 0.6,
#    'count': 1309492,
#    'unique_de': 982159,
#    'unique_en': 688800,
#    'count_reduced': 400000,
#    'unique_de_reduced': 316088,
#    'unique_en_reduced': 233837},
#   0.7: {'compression_rate': 0.7,
#    'count': 2449707,
#    'unique_de': 1849643,
#    'unique_en': 1468345,
#    'count_reduced': 400000,
#    'unique_de_reduced': 328092,
#    'unique_en_reduced': 274036},
#   0.8: {'compression_rate': 0.8,
#    'count': 4355457,
#    'unique_de': 3310545,
#    'unique_en': 2851736,
#    'count_reduced': 400000,
#    'unique_de_reduced': 336934,
#    'unique_en_reduced': 302189},
#   0.9: {'compression_rate': 0.9,
#    'count': 6620283,
#    'unique_de': 5117560,
#    'unique_en': 4615254,
#    'count_reduced': 400000,
#    'unique_de_reduced': 346855,
#    'unique_en_reduced': 322798},
#   1.0: {'compression_rate': 1.0,
#    'count': 9244596,
#    'unique_de': 6883682,
#    'unique_en': 6370028,
#    'count_reduced': 400000,
#    'unique_de_reduced': 343160,
#    'unique_en_reduced': 324993}},
#  'en-sq.csv': {'length_ratio': 1.050420763842886,
#   0.5: {'compression_rate': 0.5,
#    'count': 102869,
#    'unique_en': 87047,
#    'unique_sq': 61356,
#    'count_reduced': 102869,
#    'unique_en_reduced': 87047,
#    'unique_sq_reduced': 61356},
#   0.6: {'compression_rate': 0.6,
#    'count': 196339,
#    'unique_en': 153466,
#    'unique_sq': 119296,
#    'count_reduced': 196339,
#    'unique_en_reduced': 153466,
#    'unique_sq_reduced': 119296},
#   0.7: {'compression_rate': 0.7,
#    'count': 330680,
#    'unique_en': 256241,
#    'unique_sq': 216490,
#    'count_reduced': 330680,
#    'unique_en_reduced': 256241,
#    'unique_sq_reduced': 216490},
#   0.8: {'compression_rate': 0.8,
#    'count': 527887,
#    'unique_en': 407303,
#    'unique_sq': 365753,
#    'count_reduced': 400000,
#    'unique_en_reduced': 312747,
#    'unique_sq_reduced': 281828},
#   0.9: {'compression_rate': 0.9,
#    'count': 769454,
#    'unique_en': 604039,
#    'unique_sq': 565020,
#    'count_reduced': 400000,
#    'unique_en_reduced': 323503,
#    'unique_sq_reduced': 304615},
#   1.0: {'compression_rate': 1.0,
#    'count': 1076166,
#    'unique_en': 822514,
#    'unique_sq': 789637,
#    'count_reduced': 400000,
#    'unique_en_reduced': 320409,
#    'unique_sq_reduced': 309352}},
#  'da-en.csv': {'length_ratio': 1.2310291861796794,
#   0.5: {'compression_rate': 0.5,
#    'count': 547322,
#    'unique_da': 390627,
#    'unique_en': 252855,
#    'count_reduced': 400000,
#    'unique_da_reduced': 290580,
#    'unique_en_reduced': 191700},
#   0.6: {'compression_rate': 0.6,
#    'count': 1088999,
#    'unique_da': 758570,
#    'unique_en': 579471,
#    'count_reduced': 400000,
#    'unique_da_reduced': 295957,
#    'unique_en_reduced': 234260},
#   0.7: {'compression_rate': 0.7,
#    'count': 2236671,
#    'unique_da': 1529893,
#    'unique_en': 1317606,
#    'count_reduced': 400000,
#    'unique_da_reduced': 303005,
#    'unique_en_reduced': 269216},
#   0.8: {'compression_rate': 0.8,
#    'count': 3768359,
#    'unique_da': 2764589,
#    'unique_en': 2547985,
#    'count_reduced': 400000,
#    'unique_da_reduced': 327813,
#    'unique_en_reduced': 308072},
#   0.9: {'compression_rate': 0.9,
#    'count': 5932657,
#    'unique_da': 4214560,
#    'unique_en': 4015691,
#    'count_reduced': 400000,
#    'unique_da_reduced': 327059,
#    'unique_en_reduced': 315187},
#   1.0: {'compression_rate': 1.0,
#    'count': 7284770,
#    'unique_da': 5204357,
#    'unique_en': 5063870,
#    'count_reduced': 400000,
#    'unique_da_reduced': 330992,
#    'unique_en_reduced': 323803}},
#  'en-lt.csv': {'length_ratio': 0.9890395828668636,
#   0.5: {'compression_rate': 0.5,
#    'count': 69190,
#    'unique_en': 62838,
#    'unique_lt': 42967,
#    'count_reduced': 69190,
#    'unique_en_reduced': 62838,
#    'unique_lt_reduced': 42967},
#   0.6: {'compression_rate': 0.6,
#    'count': 134416,
#    'unique_en': 115160,
#    'unique_lt': 86738,
#    'count_reduced': 134416,
#    'unique_en_reduced': 115160,
#    'unique_lt_reduced': 86738},
#   0.7: {'compression_rate': 0.7,
#    'count': 240922,
#    'unique_en': 194281,
#    'unique_lt': 158744,
#    'count_reduced': 240922,
#    'unique_en_reduced': 194281,
#    'unique_lt_reduced': 158744},
#   0.8: {'compression_rate': 0.8,
#    'count': 372663,
#    'unique_en': 301085,
#    'unique_lt': 261321,
#    'count_reduced': 372663,
#    'unique_en_reduced': 301085,
#    'unique_lt_reduced': 261321},
#   0.9: {'compression_rate': 0.9,
#    'count': 532621,
#    'unique_en': 432657,
#    'unique_lt': 391059,
#    'count_reduced': 400000,
#    'unique_en_reduced': 328764,
#    'unique_lt_reduced': 298352},
#   1.0: {'compression_rate': 1.0,
#    'count': 664991,
#    'unique_en': 550683,
#    'unique_lt': 510136,
#    'count_reduced': 400000,
#    'unique_en_reduced': 337912,
#    'unique_lt_reduced': 314552}},
#  'en-hu.csv': {'length_ratio': 1.0121323791258023,
#   0.5: {'compression_rate': 0.5,
#    'count': 1560313,
#    'unique_en': 1231283,
#    'unique_hu': 689923,
#    'count_reduced': 400000,
#    'unique_en_reduced': 333485,
#    'unique_hu_reduced': 205280},
#   0.6: {'compression_rate': 0.6,
#    'count': 3175010,
#    'unique_en': 2361787,
#    'unique_hu': 1575052,
#    'count_reduced': 400000,
#    'unique_en_reduced': 325161,
#    'unique_hu_reduced': 239929},
#   0.7: {'compression_rate': 0.7,
#    'count': 5937986,
#    'unique_en': 4346425,
#    'unique_hu': 3300664,
#    'count_reduced': 400000,
#    'unique_en_reduced': 328644,
#    'unique_hu_reduced': 272595},
#   0.8: {'compression_rate': 0.8,
#    'count': 10178195,
#    'unique_en': 7369956,
#    'unique_hu': 6135209,
#    'count_reduced': 400000,
#    'unique_en_reduced': 331328,
#    'unique_hu_reduced': 295003},
#   0.9: {'compression_rate': 0.9,
#    'count': 15289547,
#    'unique_en': 11133057,
#    'unique_hu': 9814348,
#    'count_reduced': 400000,
#    'unique_en_reduced': 337122,
#    'unique_hu_reduced': 313081},
#   1.0: {'compression_rate': 1.0,
#    'count': 21522518,
#    'unique_en': 15220404,
#    'unique_hu': 13906350,
#    'count_reduced': 400000,
#    'unique_en_reduced': 336222,
#    'unique_hu_reduced': 319282}},
#  'en-eu.csv': {'length_ratio': 1.0873887529615953,
#   0.5: {'compression_rate': 0.5,
#    'count': 7768,
#    'unique_en': 7162,
#    'unique_eu': 5387,
#    'count_reduced': 7768,
#    'unique_en_reduced': 7162,
#    'unique_eu_reduced': 5387},
#   0.6: {'compression_rate': 0.6,
#    'count': 15606,
#    'unique_en': 14026,
#    'unique_eu': 11285,
#    'count_reduced': 15606,
#    'unique_en_reduced': 14026,
#    'unique_eu_reduced': 11285},
#   0.7: {'compression_rate': 0.7,
#    'count': 28228,
#    'unique_en': 25165,
#    'unique_eu': 21426,
#    'count_reduced': 28228,
#    'unique_en_reduced': 25165,
#    'unique_eu_reduced': 21426},
#   0.8: {'compression_rate': 0.8,
#    'count': 49363,
#    'unique_en': 42564,
#    'unique_eu': 37926,
#    'count_reduced': 49363,
#    'unique_en_reduced': 42564,
#    'unique_eu_reduced': 37926},
#   0.9: {'compression_rate': 0.9,
#    'count': 72849,
#    'unique_en': 63845,
#    'unique_eu': 58612,
#    'count_reduced': 72849,
#    'unique_en_reduced': 63845,
#    'unique_eu_reduced': 58612},
#   1.0: {'compression_rate': 1.0,
#    'count': 105692,
#    'unique_en': 88730,
#    'unique_eu': 82667,
#    'count_reduced': 105692,
#    'unique_en_reduced': 88730,
#    'unique_eu_reduced': 82667}},
#  'en-pl.csv': {'length_ratio': 1.022421730337034,
#   0.5: {'compression_rate': 0.5,
#    'count': 2105542,
#    'unique_en': 1834073,
#    'unique_pl': 1115093,
#    'count_reduced': 400000,
#    'unique_en_reduced': 363865,
#    'unique_pl_reduced': 245261},
#   0.6: {'compression_rate': 0.6,
#    'count': 3810521,
#    'unique_en': 3138643,
#    'unique_pl': 2121409,
#    'count_reduced': 400000,
#    'unique_en_reduced': 352142,
#    'unique_pl_reduced': 266109},
#   0.7: {'compression_rate': 0.7,
#    'count': 6275552,
#    'unique_en': 5010233,
#    'unique_pl': 3712490,
#    'count_reduced': 400000,
#    'unique_en_reduced': 349474,
#    'unique_pl_reduced': 286353},
#   0.8: {'compression_rate': 0.8,
#    'count': 9399322,
#    'unique_en': 7411788,
#    'unique_pl': 5913662,
#    'count_reduced': 400000,
#    'unique_en_reduced': 350148,
#    'unique_pl_reduced': 304163},
#   0.9: {'compression_rate': 0.9,
#    'count': 13174343,
#    'unique_en': 10300228,
#    'unique_pl': 8677895,
#    'count_reduced': 400000,
#    'unique_en_reduced': 352150,
#    'unique_pl_reduced': 317862},
#   1.0: {'compression_rate': 1.0,
#    'count': 17491329,
#    'unique_en': 13189304,
#    'unique_pl': 11523960,
#    'count_reduced': 400000,
#    'unique_en_reduced': 347802,
#    'unique_pl_reduced': 321991}}}
